# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from keras.datasets import fashion_mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.optimizers import Adam
from keras.layers import BatchNormalization
from keras.callbacks import ReduceLROnPlateau

# %%
# Load the dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()

# %%
# Class names for Fashion-MNIST
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Visualize some samples
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(trainX[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[trainy[i]])
plt.show()

# %%
# Reshape data to include channel dimension (grayscale so channel=1)
trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# %%
# Normalize pixel values to [0, 1]
trainX = trainX.astype('float32') / 255.0
testX = testX.astype('float32') / 255.0

# %%
# One-hot encode the labels
trainy = to_categorical(trainy)
testy = to_categorical(testy)

# %%
# Split training set into training and validation

trainX, valX, trainy, valy = train_test_split(trainX, trainy, test_size=0.1, random_state=12)
print("Training data shape:", trainX.shape)
print("Validation data shape:", valX.shape)
print("Test data shape:", testX.shape)
# Out:
# Training data shape: (54000, 28, 28, 1)
# Validation data shape: (6000, 28, 28, 1)
# Test data shape: (10000, 28, 28, 1)

# %%
# Build the CNN model
model = Sequential()

# Input layer
model.add(Input(shape=(28, 28, 1)))

# First convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

# Second convolutional layer
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

# Third convolutional layer
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))

# Flatten and dense layers
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))  # Output layer for 10 classes

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       3,211,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,583,754 (13.67 MB)
#  Trainable params: 3,583,754 (13.67 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(trainX, trainy,
                    epochs=10,
                    batch_size=128,
                    validation_data=(valX, valy))
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.7630 - loss: 0.6512 - val_accuracy: 0.8820 - val_loss: 0.3230
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.8980 - loss: 0.2758 - val_accuracy: 0.9037 - val_loss: 0.2634
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 57s 136ms/step - accuracy: 0.9203 - loss: 0.2163 - val_accuracy: 0.9168 - val_loss: 0.2307
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 55s 130ms/step - accuracy: 0.9328 - loss: 0.1801 - val_accuracy: 0.9218 - val_loss: 0.2148
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 56s 133ms/step - accuracy: 0.9463 - loss: 0.1469 - val_accuracy: 0.9192 - val_loss: 0.2223
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 55s 131ms/step - accuracy: 0.9531 - loss: 0.1271 - val_accuracy: 0.9242 - val_loss: 0.2189
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 55s 129ms/step - accuracy: 0.9633 - loss: 0.1005 - val_accuracy: 0.9225 - val_loss: 0.2428
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 55s 130ms/step - accuracy: 0.9715 - loss: 0.0785 - val_accuracy: 0.9278 - val_loss: 0.2369
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 56s 132ms/step - accuracy: 0.9760 - loss: 0.0620 - val_accuracy: 0.9215 - val_loss: 0.2659
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.9824 - loss: 0.0489 - val_accuracy: 0.9275 - val_loss: 0.2789

# %%
test_loss, test_acc = model.evaluate(testX, testy, verbose=0)
print(f'Test accuracy: {test_acc:.4f}')
print(f'Test loss: {test_loss:.4f}')
# Out:
# Test accuracy: 0.9217
# Test loss: 0.2877

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Improved model
model = Sequential()

# Input layer
model.add(Input(shape=(28, 28, 1)))

# First block
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Second block
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Third block
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

# Dense layers
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# Learning rate schedule
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# %%
# Compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the improved model
history = model.fit(trainX, trainy,
                    epochs=20,  # More epochs for better convergence
                    batch_size=64,
                    validation_data=(valX, valy),
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.7545 - loss: 0.7144 - val_accuracy: 0.8528 - val_loss: 0.3758 - learning_rate: 0.0010
# Epoch 2/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 56s 66ms/step - accuracy: 0.8665 - loss: 0.3751 - val_accuracy: 0.8972 - val_loss: 0.2765 - learning_rate: 0.0010
# Epoch 3/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 44s 53ms/step - accuracy: 0.8876 - loss: 0.3148 - val_accuracy: 0.8923 - val_loss: 0.2921 - learning_rate: 0.0010
# Epoch 4/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.8974 - loss: 0.2849 - val_accuracy: 0.9158 - val_loss: 0.2331 - learning_rate: 0.0010
# Epoch 5/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9046 - loss: 0.2655 - val_accuracy: 0.9200 - val_loss: 0.2167 - learning_rate: 0.0010
# Epoch 6/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9079 - loss: 0.2541 - val_accuracy: 0.9170 - val_loss: 0.2259 - learning_rate: 0.0010
# Epoch 7/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9144 - loss: 0.2378 - val_accuracy: 0.9180 - val_loss: 0.2232 - learning_rate: 0.0010
# Epoch 8/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9144 - loss: 0.2342 - val_accuracy: 0.9190 - val_loss: 0.2155 - learning_rate: 0.0010
# Epoch 9/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9179 - loss: 0.2218 - val_accuracy: 0.9252 - val_loss: 0.2037 - learning_rate: 0.0010
# Epoch 10/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9216 - loss: 0.2115 - val_accuracy: 0.9237 - val_loss: 0.2116 - learning_rate: 0.0010
# Epoch 11/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9245 - loss: 0.2059 - val_accuracy: 0.9122 - val_loss: 0.2457 - learning_rate: 0.0010
# Epoch 12/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9253 - loss: 0.2026 - val_accuracy: 0.9242 - val_loss: 0.2119 - learning_rate: 0.0010
# Epoch 13/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9317 - loss: 0.1886 - val_accuracy: 0.9355 - val_loss: 0.1826 - learning_rate: 2.0000e-04
# Epoch 14/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 47ms/step - accuracy: 0.9353 - loss: 0.1733 - val_accuracy: 0.9372 - val_loss: 0.1809 - learning_rate: 2.0000e-04
# Epoch 15/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9371 - loss: 0.1711 - val_accuracy: 0.9353 - val_loss: 0.1791 - learning_rate: 2.0000e-04
# Epoch 16/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 48ms/step - accuracy: 0.9409 - loss: 0.1633 - val_accuracy: 0.9377 - val_loss: 0.1795 - learning_rate: 2.0000e-04
# Epoch 17/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9400 - loss: 0.1638 - val_accuracy: 0.9310 - val_loss: 0.2050 - learning_rate: 2.0000e-04
# Epoch 18/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9416 - loss: 0.1594 - val_accuracy: 0.9378 - val_loss: 0.1846 - learning_rate: 2.0000e-04
# Epoch 19/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 47ms/step - accuracy: 0.9440 - loss: 0.1521 - val_accuracy: 0.9355 - val_loss: 0.1854 - learning_rate: 4.0000e-05
# Epoch 20/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.9431 - loss: 0.1536 - val_accuracy: 0.9363 - val_loss: 0.1799 - learning_rate: 4.0000e-05

# %%
# Evaluate improved model
test_loss, test_acc = model.evaluate(testX, testy, verbose=0)
print(f'Optimized model test accuracy: {test_acc:.4f}')
print(f'Optimized model test loss: {test_loss:.4f}')
# Out:
# Optimized model test accuracy: 0.9325
# Optimized model test loss: 0.1928
