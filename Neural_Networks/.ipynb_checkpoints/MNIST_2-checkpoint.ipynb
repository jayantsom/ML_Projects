# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from keras.datasets import fashion_mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.optimizers import Adam
from keras.layers import BatchNormalization
from keras.callbacks import ReduceLROnPlateau

# %%
# Load the dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()

# %%
# Class names for Fashion-MNIST
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Visualize some samples
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(trainX[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[trainy[i]])
plt.show()

# %%
# Reshape data to include channel dimension (grayscale so channel=1)
trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# %%
# Normalize pixel values to [0, 1]
trainX = trainX.astype('float32') / 255.0
testX = testX.astype('float32') / 255.0

# %%
# One-hot encode the labels
trainy = to_categorical(trainy)
testy = to_categorical(testy)

# %%
# Split training set into training and validation

trainX, valX, trainy, valy = train_test_split(trainX, trainy, test_size=0.1, random_state=12)
print("Training data shape:", trainX.shape)
print("Validation data shape:", valX.shape)
print("Test data shape:", testX.shape)
# Out:
# Training data shape: (54000, 28, 28, 1)
# Validation data shape: (6000, 28, 28, 1)
# Test data shape: (10000, 28, 28, 1)

# %%
# Build the CNN model
model = Sequential()

# Input layer
model.add(Input(shape=(28, 28, 1)))

# First convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

# Second convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

# Third convolutional layer
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))

# Flatten and dense layers
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))  # Output layer for 10 classes

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         802,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 896,906 (3.42 MB)
#  Trainable params: 896,906 (3.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(trainX, trainy,
                    epochs=10,
                    batch_size=64,
                    validation_data=(valX, valy))
# Out:
# Epoch 1/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.7753 - loss: 0.6147 - val_accuracy: 0.8890 - val_loss: 0.3150
# Epoch 2/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.8994 - loss: 0.2783 - val_accuracy: 0.9098 - val_loss: 0.2509
# Epoch 3/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9184 - loss: 0.2198 - val_accuracy: 0.9058 - val_loss: 0.2564
# Epoch 4/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9296 - loss: 0.1925 - val_accuracy: 0.9177 - val_loss: 0.2237
# Epoch 5/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9417 - loss: 0.1597 - val_accuracy: 0.9233 - val_loss: 0.2151
# Epoch 6/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.9503 - loss: 0.1317 - val_accuracy: 0.9215 - val_loss: 0.2252
# Epoch 7/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.9603 - loss: 0.1090 - val_accuracy: 0.9272 - val_loss: 0.2155
# Epoch 8/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9685 - loss: 0.0872 - val_accuracy: 0.9273 - val_loss: 0.2352
# Epoch 9/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.9735 - loss: 0.0714 - val_accuracy: 0.9258 - val_loss: 0.2404
# Epoch 10/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9777 - loss: 0.0574 - val_accuracy: 0.9222 - val_loss: 0.2751

# %%
test_loss, test_acc = model.evaluate(testX, testy, verbose=0)
print(f'Test accuracy: {test_acc:.4f}')
print(f'Test loss: {test_loss:.4f}')
# Out:
# Test accuracy: 0.9141
# Test loss: 0.3110

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Improved model
model = Sequential()

# Input layer
model.add(Input(shape=(28, 28, 1)))

# First block
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Second block
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Third block
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

# Dense layers
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# Learning rate schedule
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# %%
# Compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the improved model
history = model.fit(trainX, trainy,
                    epochs=20,  # More epochs for better convergence
                    batch_size=64,
                    validation_data=(valX, valy),
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.7530 - loss: 0.7269 - val_accuracy: 0.8815 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 2/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 42s 50ms/step - accuracy: 0.8712 - loss: 0.3573 - val_accuracy: 0.8988 - val_loss: 0.2709 - learning_rate: 0.0010
# Epoch 3/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.8852 - loss: 0.3160 - val_accuracy: 0.9007 - val_loss: 0.2663 - learning_rate: 0.0010
# Epoch 4/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.8983 - loss: 0.2828 - val_accuracy: 0.9127 - val_loss: 0.2395 - learning_rate: 0.0010
# Epoch 5/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 40s 47ms/step - accuracy: 0.9041 - loss: 0.2644 - val_accuracy: 0.9207 - val_loss: 0.2208 - learning_rate: 0.0010
# Epoch 6/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9090 - loss: 0.2516 - val_accuracy: 0.9127 - val_loss: 0.2459 - learning_rate: 0.0010
# Epoch 7/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9138 - loss: 0.2357 - val_accuracy: 0.9228 - val_loss: 0.2087 - learning_rate: 0.0010
# Epoch 8/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 39s 46ms/step - accuracy: 0.9165 - loss: 0.2343 - val_accuracy: 0.9253 - val_loss: 0.2045 - learning_rate: 0.0010
# Epoch 9/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9165 - loss: 0.2252 - val_accuracy: 0.9265 - val_loss: 0.2004 - learning_rate: 0.0010
# Epoch 10/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 37s 44ms/step - accuracy: 0.9208 - loss: 0.2120 - val_accuracy: 0.9233 - val_loss: 0.2038 - learning_rate: 0.0010
# Epoch 11/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 37s 44ms/step - accuracy: 0.9229 - loss: 0.2135 - val_accuracy: 0.9252 - val_loss: 0.2084 - learning_rate: 0.0010
# Epoch 12/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 37s 44ms/step - accuracy: 0.9249 - loss: 0.2023 - val_accuracy: 0.9258 - val_loss: 0.2015 - learning_rate: 0.0010
# Epoch 13/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 37s 44ms/step - accuracy: 0.9329 - loss: 0.1813 - val_accuracy: 0.9300 - val_loss: 0.1868 - learning_rate: 2.0000e-04
# Epoch 14/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 37s 44ms/step - accuracy: 0.9358 - loss: 0.1733 - val_accuracy: 0.9362 - val_loss: 0.1852 - learning_rate: 2.0000e-04
# Epoch 15/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9380 - loss: 0.1677 - val_accuracy: 0.9350 - val_loss: 0.1840 - learning_rate: 2.0000e-04
# Epoch 16/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 44ms/step - accuracy: 0.9403 - loss: 0.1635 - val_accuracy: 0.9375 - val_loss: 0.1785 - learning_rate: 2.0000e-04
# Epoch 17/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9394 - loss: 0.1628 - val_accuracy: 0.9358 - val_loss: 0.1828 - learning_rate: 2.0000e-04
# Epoch 18/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9416 - loss: 0.1561 - val_accuracy: 0.9377 - val_loss: 0.1829 - learning_rate: 2.0000e-04
# Epoch 19/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 45ms/step - accuracy: 0.9429 - loss: 0.1572 - val_accuracy: 0.9375 - val_loss: 0.1793 - learning_rate: 2.0000e-04
# Epoch 20/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 38s 44ms/step - accuracy: 0.9457 - loss: 0.1488 - val_accuracy: 0.9387 - val_loss: 0.1782 - learning_rate: 4.0000e-05

# %%
# Evaluate improved model
test_loss, test_acc = model.evaluate(testX, testy, verbose=0)
print(f'Optimized model test accuracy: {test_acc:.4f}')
print(f'Optimized model test loss: {test_loss:.4f}')
# Out:
# Optimized model test accuracy: 0.9336
# Optimized model test loss: 0.1908
